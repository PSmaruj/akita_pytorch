# %%
import torch
import torch.nn as nn
from torch import Tensor
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader,SubsetRandomSampler,ConcatDataset
import torch.nn.functional as F

from model import SeqNN

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda:0

# %%
# Create a random tensor with shape (batch_size, channels, sequence_length)
x = torch.randn(2, 4, 1048576)
x = x.to(device)

# %%
model = SeqNN()
model = model.to(device)

# %%
# model.eval()

# %%
with torch.no_grad():  # Disable gradient calculation to speed up inference
    output = model(x, training=False)
# Out:
# Input seq_1hot shape: torch.Size([2, 4, 1048576])
# End shape: torch.Size([2, 64, 512, 512])

# %%
# from torchsummary import summary

# summary(model, (2, 4, 1048576))

# %%
from torchinfo import summary

summary(model, input_size=(2, 4, 1048576), col_names=["output_size", "num_params"])
# Out:
# Input seq_1hot shape: torch.Size([2, 4, 1048576])
# End shape: torch.Size([2, 64, 512, 512])
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# SeqNN                                    [2, 64, 512, 512]         --
# ├─StochasticReverseComplement: 1-1       [2, 4, 1048576]           --
# ├─StochasticShift: 1-2                   [2, 4, 1048576]           --
# ├─ReLU: 1-3                              [2, 4, 1048576]           --
# ├─ConvBlock: 1-4                         [2, 96, 524288]           --
# │    └─Conv1d: 2-1                       [2, 96, 1048576]          4,224
# │    └─BatchNorm1d: 2-2                  [2, 96, 1048576]          192
# │    └─MaxPool1d: 2-3                    [2, 96, 524288]           --
# ├─ConvTower: 1-5                         [2, 96, 512]              --
# │    └─Sequential: 2-4                   [2, 96, 512]              --
# │    │    └─ReLU: 3-1                    [2, 96, 524288]           --
# ...

# %%
# summary(model, input_size=(1, 1048576, 4), col_names=["output_size", "num_params"])
